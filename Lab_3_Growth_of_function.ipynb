# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehal662/Arithmetic_Problem_Solving/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )
def even_odd(a, b):
    return a % b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    even_odd(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity")
plt.grid(True, which = 'both', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)
import matplotlib.pyplot as plt
import numpy as np
import timeit
def get_first_element(data_list):
    return data_list[0]
ns = np.linspace(10, 100000, 50, dtype=int)
ts = []
for n in ns:
    data_list = list(range(n))
    time_taken = timeit.timeit(
        'get_first_element(data_list)',
        globals={'get_first_element': get_first_element, 'data_list': data_list},
        number=10000)
    ts.append(time_taken)
plt.figure(figsize=(10, 6))
plt.plot(ns, ts, 'o', markersize=4, color='red')
plt.title('Time Complexity of O(1) Accessing First Element')
plt.xlabel('n')
plt.ylabel('Time taken (ms, avg. over 10000 runs)')
plt.grid(True, which = 'both', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
import matplotlib.pyplot as plt
def binary_search(arr, target):
    left = 0
    right = len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1
sorted_list = [2, 5, 8, 12, 16, 23, 38, 56, 72, 91]
target_value = 23
result_index = binary_search(sorted_list, target_value)
plt.figure(figsize=(8, 4))
plt.plot(range(len(sorted_list)), sorted_list, marker='o', linestyle='-', label='Array Elements')
if result_index != -1:
    plt.scatter(result_index, target_value, color='red', s = 100, label='Target Found')
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Binary Search")
plt.legend()
plt.grid(True, which = 'both', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
import random
import time
import matplotlib.pyplot as plt
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result
input_sizes = [100, 500, 1000, 2000, 4000, 8000]
times = []
for n in input_sizes:
    arr = [random.randint(0, n) for _ in range(n)]
    start = time.time()
    merge_sort(arr)
    end = time.time()
    times.append(end - start)
plt.figure(figsize=(8, 5))
plt.plot(input_sizes, times, marker='o')
plt.xlabel("Input Size (n)")
plt.ylabel("Time (seconds)")
plt.title("Merge Sort Time Complexity")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import random
import time
import matplotlib.pyplot as plt
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result
input_sizes = [100, 500, 1000, 2000, 4000, 8000]
times = []
for n in input_sizes:
    arr = [random.randint(0, n) for _ in range(n)]
    start = time.time()
    merge_sort(arr)
    end = time.time()
    times.append(end - start)
plt.figure(figsize=(8, 5))
plt.plot(input_sizes, times, marker='o')
plt.xlabel("Input Size (n)")
plt.ylabel("Time (seconds)")
plt.title("Merge Sort Time Complexity")
plt.grid(True)
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import time
import random
import matplotlib.pyplot as plt
import numpy as np
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_sorted = merge_sort(left_half)
    right_sorted = merge_sort(right_half)

    return merge(left_sorted, right_sorted)
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result
def plot_performance():
    input_sizes = [100, 500, 1000, 2000, 4000, 8000, 16000]
    runtimes = []
    for n in input_sizes:
        data = [random.randint(0, 100000) for _ in range(n)]

        start_time = time.time()
        merge_sort(data)
        end_time = time.time()

        duration = end_time - start_time
        runtimes.append(duration)
        print(f"Size: {n}, Time: {duration:.6f} seconds")
    plt.figure(figsize=(10, 6))
    plt.plot(input_sizes, runtimes, 'bo-', label='Measured Merge Sort Time')
    n_array = np.array(input_sizes)
    theoretical_curve = 0.0000005 * n_array * np.log(n_array)
    plt.plot(input_sizes, theoretical_curve, 'r--', label='Theoretical O(n log n) Curve')
    plt.xlabel('n')
    plt.ylabel('Time in Seconds')
    plt.title('Performance of Merge Sort (Log-Linear Time)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import matplotlib.pyplot as plt
import numpy as np
n = np.linspace(1, 100, 100)
n_log = np.linspace(2, 100, 99)
O_1 = np.ones(n.shape)
O_log_n = np.log(n_log)
O_n = n
O_n_log_n = n * np.log(n)
O_n_squared = n**2
O_2_pow_n = 2**n
plt.figure(figsize=(12, 8))
plt.plot(n, O_1, label='O(1) - Constant', color='black', linestyle='--')
plt.plot(n_log, O_log_n, label='O(log n) - Logarithmic', color='green')
plt.plot(n, O_n, label='O(n) - Linear', color='blue')
plt.plot(n, O_n_log_n, label='O(n log n) - Linearithmic', color='purple')
plt.plot(n, O_n_squared, label='O(n²) - Quadratic', color='orange')
plt.plot(n, O_2_pow_n, label='O(2^n) - Exponential', color='red')
plt.xlabel('n')
plt.ylabel('Time Complexity')
plt.title('Time Complexity of Common Functions')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.ylim(0, 500)
plt.xlim(1, 100)
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)
import matplotlib.pyplot as plt
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0]
        less = [i for i in arr[1:] if i <= pivot]
        greater = [i for i in arr[1:] if i > pivot]
        return quick_sort(less) + [pivot] + quick_sort(greater)
my_list = [3, 6, 8, 10, 1, 2, 1]
sorted_list = quick_sort(my_list)
print(f"Original list: {my_list}")
print(f"Sorted list: {sorted_list}")
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.bar(range(len(my_list)), my_list)
plt.title("Original List")
plt.xlabel("Index")
plt.ylabel("Value")
plt.subplot(1, 2, 2)
plt.bar(range(len(sorted_list)), sorted_list)
plt.title("Sorted List (Quick Sort)")
plt.xlabel("Index")
plt.ylabel("Value")
plt.tight_layout()
plt.show()
# Out:
# Original list: [3, 6, 8, 10, 1, 2, 1]
# Sorted list: [1, 1, 2, 3, 6, 8, 10]
